# %%
import sys
# !{sys.executable} -m pip install great_expectations[spark]==1.6.3
# !{sys.executable} -m pip install typing_extensions==4.14.1 --upgrade
# Out:
# Collecting great_expectations==1.6.3 (from great_expectations[spark]==1.6.3)
#   Downloading great_expectations-1.6.3-py3-none-any.whl.metadata (9.3 kB)
# Collecting altair<5.0.0,>=4.2.1 (from great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading altair-4.2.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cryptography>=3.2 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (41.0.4)
# Requirement already satisfied: jinja2>=3 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (3.1.2)
# Requirement already satisfied: jsonschema>=2.5.1 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (4.19.1)
# Collecting marshmallow<4.0.0,>=3.7.1 (from great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: mistune>=0.8.4 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (3.0.1)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (1.24.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (23.2)
# Requirement already satisfied: pandas<2.2,>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2.0.3)
# Collecting posthog>3 (from great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading posthog-7.0.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting pydantic>=1.10.7 (from great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.2.4,>=2.4 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2.8.2)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2.31.0)
# Requirement already satisfied: ruamel.yaml>=0.16 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (0.17.39)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (1.11.3)
# Requirement already satisfied: tqdm>=4.59.0 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.11/site-packages (from great_expectations==1.6.3->great_expectations[spark]==1.6.3) (4.8.0)
# Collecting tzlocal>=1.2 (from great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pyspark<4.0,>=2.3.2 in /usr/local/spark/python (from great_expectations[spark]==1.6.3) (3.5.0)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.1->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (0.4)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.1->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=3.2->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.5.1->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.5.1->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.5.1->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.5.1->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (0.10.6)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<2.2,>=1.3.0->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas<2.2,>=1.3.0->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from posthog>3->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (1.16.0)
# Collecting backoff>=1.10.0 (from posthog>3->great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog>3->great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.10.7->great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=1.10.7->great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading pydantic_core-2.41.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-extensions>=4.1.0 (from great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=1.10.7->great_expectations==1.6.3->great_expectations[spark]==1.6.3)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting py4j==0.10.9.7 (from pyspark<4.0,>=2.3.2->great_expectations[spark]==1.6.3)
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.20->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.20->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.20->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.20->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2023.7.22)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.11/site-packages (from ruamel.yaml>=0.16->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (0.2.7)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations==1.6.3->great_expectations[spark]==1.6.3) (2.21)
# Downloading great_expectations-1.6.3-py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.7 MB/s eta 0:00:0000:0100:01
# Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 45.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.1 MB/s eta 0:00:00
# Downloading posthog-7.0.1-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.2/145.2 kB 15.9 MB/s eta 0:00:00
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.4/463.4 kB 36.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.5 MB/s eta 0:00:00
# Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 20.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.8 MB/s eta 0:00:00
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: py4j, tzlocal, typing-extensions, marshmallow, distro, backoff, annotated-types, typing-inspection, pydantic-core, posthog, pydantic, altair, great_expectations
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: altair
#     Found existing installation: altair 5.1.2
#     Uninstalling altair-5.1.2:
#       Successfully uninstalled altair-5.1.2
# Successfully installed altair-4.2.2 annotated-types-0.7.0 backoff-2.2.1 distro-1.9.0 great_expectations-1.6.3 marshmallow-3.26.1 posthog-7.0.1 py4j-0.10.9.7 pydantic-2.12.4 pydantic-core-2.41.5 typing-extensions-4.15.0 typing-inspection-0.4.2 tzlocal-5.3.1
# Collecting typing_extensions==4.14.1
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: typing_extensions
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
# Successfully installed typing_extensions-4.14.1

# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf
from pyspark.sql.functions import *

sparkConf = SparkConf()
sparkConf.setMaster("spark://spark-master:7077")
sparkConf.setAppName("Lab9_DataQuality_Example")
sparkConf.set("spark.driver.memory", "2g")
sparkConf.set("spark.executor.cores", "1")
sparkConf.set("spark.driver.cores", "1")
# create the Spark session, which is the entry point to the Spark SQL engine.
spark = SparkSession.builder.config(conf=sparkConf).getOrCreate()
spark_df = spark.read.format("csv").option("header", "true") \
       .load("/home/jovyan/data/restaurants_quality_issues.csv")
spark_df.printSchema()

#Data Conversion

spark_df = spark_df.withColumn("rid", col("rid").cast("int")) \
       .withColumn("avg_price", col("avg_price").cast("float")) \
       .withColumn("rating", col("rating").cast("float")) \
       .withColumn("contact", col("contact").cast("string"))
spark_df.printSchema()
spark_df.show(100)
# Out:
# root
#  |-- rid: string (nullable = true)
#  |-- avg_price: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- contact: string (nullable = true)
#
# root
#  |-- rid: integer (nullable = true)
#  |-- avg_price: float (nullable = true)
#  |-- rating: float (nullable = true)
#  |-- contact: string (nullable = true)
#
# +----+---------+------+--------------------+
# | rid|avg_price|rating|             contact|
# +----+---------+------+--------------------+
# |   1|    58.98|  2.49|lbuckeridge0@indi...|
# |   2|    60.32|  3.69|wstrickland1@goog...|
# |   3|    61.94|  2.57|smiroy2@delicious...|
# |   4|    77.15|  4.34|radamoli3@google....|
# |   5|    36.39|  3.78|  cwiersma4@etsy.com|
# |   6|    36.03|  3.23|fleteve5@wundergr...|
# |   7|    31.24|  3.59|bkoschek6@spiegel.de|
# |   8|    67.21|  3.69|   llansly7@sohu.com|
# |   9|    37.06|  3.03|bmatton8@edublogs...|
# |  10|    51.98|  2.15|     bdinis9@fda.gov|
# |  11|    46.37| 11.86|   wdaysha@phpbb.com|
# |  12|    89.75|  3.16|rbaddileyb@unesco...|
# |  13|    52.08|  0.63|   gcruxtonc@com.com|
# |  14|    74.46|  2.47|lpuncherd@xinhuan...|
# |  15|    48.42| 20.14|  lheijnene@narod.ru|
# |  16|    48.82|  4.24|  fabreyf@hao123.com|
# |  17|    52.19| -4.96|hchantillong@lulu...|
# |  18|     43.9|  2.58|poscandallh@myspa...|
# |  19|    50.37|  2.44|  lsugarmani@mail.ru|
# |  20|    68.07|  2.15| msauvagej@google.it|
# |  21|    22.88|  3.97|lgildersleavesk@w...|
# |  22|    35.66|  5.11|mculbardl@prnewsw...|
# |  23|    66.54|  3.24|tkleinpeltzmlist-...|
# |  24|    48.36|  3.18|agymlettn@marriot...|
# |  25|    62.16|  5.16|    hhyndeso@fc2.com|
# |  26|     48.8|  4.25|cgillcristp@techc...|
# |  27|    16.18|  2.31|  efirbanksq@epa.gov|
# |  28|     8.04|   2.8| jcouroyr@tripod.com|
# |  29|    48.22|  3.59|wlillies@marketwa...|
# |  30|    72.69|  3.13|    nalvent@cnet.com|
# |  31|    68.66|  4.88|ngollingu@illinoi...|
# |  32|    43.27|   3.6|mbortolussiv@weeb...|
# |  33|    40.92|  2.53|                NULL|
# |  34|    53.28|   2.7|  aarntzenx@ehow.com|
# |  35|    58.77|  3.34|ithreddery@wordpr...|
# |  36|    62.79|  3.38|dcocksedgez@samsu...|
# |  37|     7.12|  3.42|sgeyton10@virgini...|
# |  38|    20.86|  3.49|ccortez11themefor...|
# |  39|    46.87|  2.56|ahollingby12@home...|
# |  40|    37.37|  3.56|bpainter13@statco...|
# |  41|    43.39|  2.83|comara14@marketwa...|
# |  42|    46.29|   3.6|jmarcome15@histat...|
# |  43|    71.88|  2.95|                NULL|
# |  44|    39.49|  1.35|aashford17@hc360.com|
# |  45|    16.47|  1.36|  mslora18@amazon.de|
# |  46|    57.13|  4.05|     clight19@gov.uk|
# |  47|    29.75|   4.5|acorkel1a@webeden...|
# |  48|    32.75|  2.27| rgauford1b@jugem.jp|
# |  49|    70.53|  3.25|  hsoar1c@devhub.com|
# |  50|    72.42|  2.86|rbarz1d@networkso...|
# |NULL|    48.79|  1.68|dashbe1e@youtube.com|
# |  52|    51.32|  2.87|pstempe1f@abc.net.au|
# |NULL|    43.08|  2.96|aswayland1g@amebl...|
# |  54|    32.12|  3.07|shannabus1h@harva...|
# |  55|    15.86|  2.92|plawrinson1i@amaz...|
# |  56|    36.85|  2.67|amegarrell1j@miib...|
# |  57|    33.33|  2.83|akniveton1k@ucoz.com|
# |  58|    41.56|  1.61|tlerhinan1l@zimbi...|
# |  59|    40.08|  3.91|emcgraffin1m@site...|
# |  60|    40.34|  4.15|bthatcham1n@hista...|
# |  61|     58.1|  2.94|qjeacocke1o@spoti...|
# |  62|     78.2|  2.33|fhawthorn1p@yande...|
# |  63|    86.97|  3.69|rbatman1q@bigcart...|
# |  64|    50.14|  4.96|mstag1r@eventbrit...|
# |  65|    68.19|  1.71|dkrysztofowicz1s@...|
# |  66|    59.18|  2.11|  cgrundy1t@uiuc.edu|
# |  67|    35.24|  3.91| vbrooking1u@ovh.net|
# |  68|    40.24|   5.4|  cknappen1v@mail.ru|
# |  69|    57.95|   3.9|mkopke1w@vkontakt...|
# |  70|    55.78|  2.48|amilnes1x@amazon....|
# |  71|    55.14|  4.95|mlesaunier1y@hc36...|
# |  72|    55.86|   3.9|lbertelmot1z@chro...|
# |  73|    49.25|  3.01|tspringtorpe20@in...|
# |  74|    75.81|  2.48|rinchley21@nydail...|
# |  75|    29.69|  4.23| lcubuzzi22@sohu.com|
# |  76|    80.22|  2.94|ailsley23@tripod.com|
# |  77|    23.29|  1.99|      mpindar24@t.co|
# |  78|    45.69|  2.53|     fdohms25@wp.com|
# |  79|    60.89|  5.58|koswick26@pintere...|
# |  80|    66.67|  2.54|bmonument27@china...|
# |  81|    63.46|  1.73|   temery28@jugem.jp|
# |  82|    19.41|  2.07| caxel29@yahoo.co.jp|
# |  83|    45.18|  2.03|adulinty2a@ocn.ne.jp|
# |  84|     50.6|  2.73|mheskey2b@mayocli...|
# |  85|    39.28|  3.62|jwanden2c@guardia...|
# |  86|    33.35|  3.43|hvallery2d@nymag.com|
# |  87|    31.65|  2.65|mscopyn2e@dedecms...|
# |  88|    32.97|  2.73|rcostard2f@networ...|
# |  89|    29.56|   3.1|fmatthewman2g@cra...|
# |  90|    69.25|  2.89|carnault2h@angelf...|
# |  91|    69.65|  3.81|   mninotti2i@ca.gov|
# |  92|    86.42|  2.31|jwakelin2j@google.ru|
# |  93|    22.45|  1.44| ksarfat2k@jimdo.com|
# |  94|    10.54|  2.82|rkinsman2l@pagesp...|
# |  95|    72.96|   2.2|   gdeye2m@adobe.com|
# |  96|    64.79|   2.6|krosson2n@amazon....|
# |  97|    36.54|  3.85|dosbidston2o@goog...|
# |  98|   102.67|  3.62|pohaire2p@unesco.org|
# |  99|    40.48|  4.58|rcalterone2q@inde...|
# | 100|    41.03|   3.2| geasun2r@hao123.com|
# +----+---------+------+--------------------+
# only showing top 100 rows

# %% [markdown]
# ### Look for Available Expectations at https://greatexpectations.io/expectations/

# %%
import great_expectations as gx
import json
# Get a context.
context = gx.get_context()

# Create a suite
expectation_ratingc = gx.expectations.ExpectColumnValuesToBeBetween(
    column="rating", min_value=0, max_value=6
)
expectation_contact = gx.expectations.ExpectColumnValuesToMatchRegex(
    column="contact", regex=r"^([a-z0-9_\.-]+)@([\da-z\.-]+)\.([a-z\.]{2,6})$"
)
expectation_rid = gx.expectations.ExpectColumnValuesToNotBeNull(
    column="rid"
)
expectation_contact_null = gx.expectations.ExpectColumnValuesToNotBeNull(
    column="contact"
)

suite = context.suites.add(gx.ExpectationSuite(name="restaurants_suite"))
suite.add_expectation(expectation_ratingc)
suite.add_expectation(expectation_contact)
suite.add_expectation(expectation_rid)
suite.add_expectation(expectation_contact_null)

# Configure data to validate
datasource = context.data_sources.add_spark(name="restaurants_spark")
asset = datasource.add_dataframe_asset(name="restaurants_asset")
bd = asset.add_batch_definition_whole_dataframe(name="restaurants_bd")

# Configure and run the validation
vd = gx.ValidationDefinition(
    name="restaurants_vd",
    data=bd,
    suite=suite,
)
context.validation_definitions.add(vd)
checkpoint = gx.Checkpoint(
    name="restaurants_checkpoint", 
    validation_definitions=[vd], 
    actions=[gx.checkpoint.UpdateDataDocsAction(name="update_data_docs")]
)
context.checkpoints.add(checkpoint)
# Look at results
results = checkpoint.run(batch_parameters={"dataframe": spark_df})
context.open_data_docs()
results_report = results.describe()
print(results_report)
json_report = json.loads(results_report)
print("***JSON Version***")
print(json_report)
# Out:
# Calculating Metrics:   0%|          | 0/31 [00:00<?, ?it/s]
# {
#     "success": false,
#     "statistics": {
#         "evaluated_validations": 1,
#         "success_percent": 0.0,
#         "successful_validations": 0,
#         "unsuccessful_validations": 1
#     },
#     "validation_results": [
#         {
#             "success": false,
#             "statistics": {
#                 "evaluated_expectations": 4,
#                 "successful_expectations": 0,
#                 "unsuccessful_expectations": 4,
#                 "success_percent": 0.0
#             },
#             "expectations": [
#                 {
#                     "expectation_type": "expect_column_values_to_be_between",
#                     "success": false,
#                     "kwargs": {
#                         "batch_id": "restaurants_spark-restaurants_asset",
#                         "column": "rating",
#                         "min_value": 0.0,
#                         "max_value": 6.0
#                     },
#                     "result": {
#                         "element_count": 865,
#                         "unexpected_count": 6,
#                         "unexpected_percent": 0.6936416184971098,
#                         "partial_unexpected_list": [
#                             11.859999656677246,
#                             20.139999389648438,
#                             -4.960000038146973,
#                             6.050000190734863,
#                             6.130000114440918,
#                             -0.09000000357627869
#                         ],
#                         "missing_count": 0,
#                         "missing_percent": 0.0,
#                         "unexpected_percent_total": 0.6936416184971098,
#                         "unexpected_percent_nonmissing": 0.6936416184971098,
#                         "partial_unexpected_counts": [
#                             {
#                                 "value": -4.960000038146973,
#                                 "count": 1
#                             },
#                             {
#                                 "value": -0.09000000357627869,
#                                 "count": 1
#                             },
#                             {
#                                 "value": 6.050000190734863,
#                                 "count": 1
#                             },
#                             {
#                                 "value": 6.130000114440918,
#                                 "count": 1
#                             },
#                             {
#                                 "value": 11.859999656677246,
#                                 "count": 1
#                             },
#                             {
#                                 "value": 20.139999389648438,
#                                 "count": 1
#                             }
#                         ]
#                     }
#                 },
#                 {
#                     "expectation_type": "expect_column_values_to_match_regex",
#                     "success": false,
#                     "kwargs": {
#                         "batch_id": "restaurants_spark-restaurants_asset",
#                         "column": "contact",
#                         "regex": "^([a-z0-9_\\.-]+)@([\\da-z\\.-]+)\\.([a-z\\.]{2,6})$"
#                     },
#                     "result": {
#                         "element_count": 865,
#                         "unexpected_count": 2,
#                         "unexpected_percent": 0.2317497103128621,
#                         "partial_unexpected_list": [
#                             "tkleinpeltzmlist-manage.com",
#                             "ccortez11themeforest.net"
#                         ],
#                         "missing_count": 2,
#                         "missing_percent": 0.23121387283236997,
#                         "unexpected_percent_total": 0.23121387283236997,
#                         "unexpected_percent_nonmissing": 0.2317497103128621,
#                         "partial_unexpected_counts": [
#                             {
#                                 "value": "ccortez11themeforest.net",
#                                 "count": 1
#                             },
#                             {
#                                 "value": "tkleinpeltzmlist-manage.com",
#                                 "count": 1
#                             }
#                         ]
#                     }
#                 },
#                 {
#                     "expectation_type": "expect_column_values_to_not_be_null",
#                     "success": false,
#                     "kwargs": {
#                         "batch_id": "restaurants_spark-restaurants_asset",
#                         "column": "contact"
#                     },
#                     "result": {
#                         "element_count": 865,
#                         "unexpected_count": 2,
#                         "unexpected_percent": 0.23121387283236997,
#                         "partial_unexpected_list": [
#                             null,
#                             null
#                         ],
#                         "partial_unexpected_counts": [
#                             {
#                                 "value": null,
#                                 "count": 2
#                             }
#                         ]
#                     }
#                 },
#                 {
#                     "expectation_type": "expect_column_values_to_not_be_null",
#                     "success": false,
#                     "kwargs": {
#                         "batch_id": "restaurants_spark-restaurants_asset",
#                         "column": "rid"
#                     },
#                     "result": {
#                         "element_count": 865,
#                         "unexpected_count": 2,
#                         "unexpected_percent": 0.23121387283236997,
#                         "partial_unexpected_list": [
#                             null,
#                             null
#                         ],
#                         "partial_unexpected_counts": [
#                             {
#                                 "value": null,
#                                 "count": 2
#                             }
#                         ]
#                     }
#                 }
#             ],
#             "result_url": null
#         }
#     ]
# }
# ***JSON Version***
# {'success': False, 'statistics': {'evaluated_validations': 1, 'success_percent': 0.0, 'successful_validations': 0, 'unsuccessful_validations': 1}, 'validation_results': [{'success': False, 'statistics': {'evaluated_expectations': 4, 'successful_expectations': 0, 'unsuccessful_expectations': 4, 'success_percent': 0.0}, 'expectations': [{'expectation_type': 'expect_column_values_to_be_between', 'success': False, 'kwargs': {'batch_id': 'restaurants_spark-restaurants_asset', 'column': 'rating', 'min_value': 0.0, 'max_value': 6.0}, 'result': {'element_count': 865, 'unexpected_count': 6, 'unexpected_percent': 0.6936416184971098, 'partial_unexpected_list': [11.859999656677246, 20.139999389648438, -4.960000038146973, 6.050000190734863, 6.130000114440918, -0.09000000357627869], 'missing_count': 0, 'missing_percent': 0.0, 'unexpected_percent_total': 0.6936416184971098, 'unexpected_percent_nonmissing': 0.6936416184971098, 'partial_unexpected_counts': [{'value': -4.960000038146973, 'count': 1}, {'value': -0.09000000357627869, 'count': 1}, {'value': 6.050000190734863, 'count': 1}, {'value': 6.130000114440918, 'count': 1}, {'value': 11.859999656677246, 'count': 1}, {'value': 20.139999389648438, 'count': 1}]}}, {'expectation_type': 'expect_column_values_to_match_regex', 'success': False, 'kwargs': {'batch_id': 'restaurants_spark-restaurants_asset', 'column': 'contact', 'regex': '^([a-z0-9_\\.-]+)@([\\da-z\\.-]+)\\.([a-z\\.]{2,6})$'}, 'result': {'element_count': 865, 'unexpected_count': 2, 'unexpected_percent': 0.2317497103128621, 'partial_unexpected_list': ['tkleinpeltzmlist-manage.com', 'ccortez11themeforest.net'], 'missing_count': 2, 'missing_percent': 0.23121387283236997, 'unexpected_percent_total': 0.23121387283236997, 'unexpected_percent_nonmissing': 0.2317497103128621, 'partial_unexpected_counts': [{'value': 'ccortez11themeforest.net', 'count': 1}, {'value': 'tkleinpeltzmlist-manage.com', 'count': 1}]}}, {'expectation_type': 'expect_column_values_to_not_be_null', 'success': False, 'kwargs': {'batch_id': 'restaurants_spark-restaurants_asset', 'column': 'contact'}, 'result': {'element_count': 865, 'unexpected_count': 2, 'unexpected_percent': 0.23121387283236997, 'partial_unexpected_list': [None, None], 'partial_unexpected_counts': [{'value': None, 'count': 2}]}}, {'expectation_type': 'expect_column_values_to_not_be_null', 'success': False, 'kwargs': {'batch_id': 'restaurants_spark-restaurants_asset', 'column': 'rid'}, 'result': {'element_count': 865, 'unexpected_count': 2, 'unexpected_percent': 0.23121387283236997, 'partial_unexpected_list': [None, None], 'partial_unexpected_counts': [{'value': None, 'count': 2}]}}], 'result_url': None}]}

# %%
# Get Summary
for validation_result in json_report.get('validation_results', []):
    for expectation_item in validation_result.get('expectations', []):
        print(expectation_item['expectation_type'], expectation_item.get('result', []).get('unexpected_count', 'Success'))
# Out:
# expect_column_values_to_be_between 6
# expect_column_values_to_match_regex 2
# expect_column_values_to_not_be_null 2
# expect_column_values_to_not_be_null 2

# %%
# Stop the Spark context
spark.stop()
